# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option("display.max_columns",100)
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Data overview

# %% [markdown]
# This dataset contains information on default payments, demographic factors, credit data, history of payment, and bill statements of credit card clients in Taiwan from April 2005 to September 2005.

# %% [markdown]
# - ID: ID of each client
# - LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
# - SEX: Gender (1=male, 2=female)
# - EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others)
# - MARRIAGE: Marital status (1=married, 2=single, 3=others)
# - AGE: Age in years
# - PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two - months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# - PAY_2: Repayment status in August, 2005 (scale same as above)
# - PAY_3: Repayment status in July, 2005 (scale same as above)
# - PAY_4: Repayment status in June, 2005 (scale same as above)
# - PAY_5: Repayment status in May, 2005 (scale same as above)
# - PAY_6: Repayment status in April, 2005 (scale same as above)
# - BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# - BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# - BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# - BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# - BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# - BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# - PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# - PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# - PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# - PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# - PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# - PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# - default.payment.next.month: Default payment in June, 2005 (1=yes, 0=no)

# %% [markdown]
# ### Read data

# %%
filepath = 'data.xls'
data = pd.read_excel(filepath,header=1)
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#    id  limit_bal  sex  education  marriage  age  pay_0  pay_2  pay_3  pay_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    pay_5  pay_6  bill_amt1  bill_amt2  bill_amt3  bill_amt4  bill_amt5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  pay_amt5  pay_amt6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0

# %%
data.rename(columns={'default payment next month':'default'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# id           30000 non-null int64
# limit_bal    30000 non-null int64
# sex          30000 non-null int64
# education    30000 non-null int64
# marriage     30000 non-null int64
# age          30000 non-null int64
# pay_0        30000 non-null int64
# pay_2        30000 non-null int64
# pay_3        30000 non-null int64
# pay_4        30000 non-null int64
# pay_5        30000 non-null int64
# pay_6        30000 non-null int64
# bill_amt1    30000 non-null int64
# bill_amt2    30000 non-null int64
# bill_amt3    30000 non-null int64
# bill_amt4    30000 non-null int64
# bill_amt5    30000 non-null int64
# bill_amt6    30000 non-null int64
# pay_amt1     30000 non-null int64
# pay_amt2     30000 non-null int64
# pay_amt3     30000 non-null int64
# pay_amt4     30000 non-null int64
# pay_amt5     30000 non-null int64
# pay_amt6     30000 non-null int64
# default      30000 non-null int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
g_default = data.groupby('default').size().reset_index()
g_default.columns = ['default','count']

# %%
g_default
# Out:
#    default  count
# 0        0  23364
# 1        1   6636

# %%
fig , ax = plt.subplots()
ax.bar(g_default['default'],g_default['count'],width=0.7,color=['g','b'],alpha=0.5)
ax.set_title('Distribution of default payment')
ax.set_xticks([0,1])
ax.set_xlabel('Default payment')
ax.set_ylabel('count')
for i, v in enumerate(g_default['count']):
    ax.text( i -.08,v/2, str(v), color='black', fontweight='bold')

# %%
ax = sns.countplot(x='default',data=data,alpha=0.5)
for i, v in enumerate(g_default['count']):
    ax.text( i -.07,v/2, str(v), color='black', fontweight='bold')

# %%
ax = sns.countplot(x='sex',hue='education',data=data)

# %% [markdown]
# <div class='alert alert-block alert-success' style="font-weight:bolder">
#
# ### Task1
#
# ### 1- Bar plot count of each education level per class.
#
# ### 2- Bar plot count of each marriage level per class.
#
# </div>

# %%
# display valid values only
g_education = data.groupby('education').size().reset_index()
g_education.columns = ['edu','count']
g_education['edu'] = g_education['edu'][1:5]

fig , ax = plt.subplots()
ax.bar(g_education['edu'],g_education['count'],width=0.7,color=['g','b'],alpha=0.5)
ax.set_title('Distribution of education level')
ax.set_xticks([1,2,3,4])
ax.set_xlabel('Education level')
ax.set_ylabel('count')
for i, v in enumerate(g_education['count']):
    if i > 0 and i < 5:
        ax.text( i -0.1, v/2, str(v), color='black', fontweight='bold')

# %%
# display only valid values
g_marriage = data.groupby('marriage').size().reset_index()
g_marriage.columns = ['marriage','count']
g_marriage['marriage'] = g_marriage['marriage'][1:4]

fig , ax = plt.subplots()
ax.bar(g_marriage['marriage'],g_marriage['count'],width=0.7,color=['g','b'],alpha=0.5)
ax.set_title('Distribution of default payment')
ax.set_xticks([1,2,3])
ax.set_xlabel('Marriage status')
ax.set_ylabel('count')
for i, v in enumerate(g_marriage['count']):
    if i > 0:
        ax.text( i-0.1, v/2, str(v), color='black', fontweight='bold')

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### Histogram
#
# </div>

# %% [markdown]
# ### Histogram of age with matplotlib

# %%
fig,ax = plt.subplots()
n, bins, patches = plt.hist(data['age'],bins=100,facecolor='w',edgecolor='b',alpha=0.7,density=0)

# %% [markdown]
# ### Histogram of age with seaborn

# %%
sns.distplot(data['age'],bins=30,hist_kws={"edgecolor": 'b',"facecolor":'w'})

# %% [markdown]
# ### Histogram of age for each class on same figure

# %%
fig,ax = plt.subplots()
sns.distplot(data[data['default']==0]['age'],bins=30,hist_kws={"facecolor":'y'})
sns.distplot(data[data['default']==1]['age'],bins=30,hist_kws={"facecolor":'r'})

# %% [markdown]
# ### Histogram of age for each class on separate axes

# %%
fig, axs = plt.subplots(nrows=1,ncols=2)
sns.distplot(data[data['default']==0]['age'],bins=30,hist_kws={"facecolor":'y'},ax=axs[0])
sns.distplot(data[data['default']==1]['age'],bins=30,hist_kws={"facecolor":'r'},ax=axs[1])

# %% [markdown]
# <div class='alert alert-block alert-success' style="font-weight:bolder">
#
# ### Task2
#
# ### Plot the histogram of education for each class on separate axes
#
# Hint: There are 7 categoricatl levels for education. Use a subplots of size (2,4) and inside a for loop plot the histograms.
#
# </div>

# %%
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(15,10))
for i in range(2):
    for j in range(4):
        
        sns.distplot(data[data['education']==i*4 + j]['age'], bins=30, hist_kws={"facecolor":'y'}, ax=axs[i, j])

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### Scatter Plot
#
#
#
# </div>

# %% [markdown]
# ### Matplotlib: Scatter plot of "bill_amt6" vs "pay_amt5"

# %%
fig, ax = plt.subplots()
ax.scatter(data['bill_amt6'],data['pay_amt5'],c=data['default'],alpha=0.5)
ax.set_xlabel('bill_amt6 (April)')
ax.tick_params(axis='x',rotation=45)

# %% [markdown]
# ### Seaborn: Scatter plot of "bill_amt6" vs "pay_amt5"

# %%
sns.scatterplot(x='bill_amt6',y='pay_amt5',hue='default',data=data)

# %% [markdown]
# <div class='alert alert-block alert-success' style="font-weight:bolder">
#
# ### Task3
#
# ### In a foor loop plot the scatter for bill and pay for other months
#
#
# </div>

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,10))

for i in range(2):
    for j in range(3):
        ix = i*3+j+1
        sns.scatterplot(x='pay_amt{}'.format(ix), y='bill_amt{}'.format(ix), hue='default', data=data, ax=axs[i, j])

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### Pair Plot
#
# Using bar plot to illusterate the number of default payment in each class.
#
# </div>

# %%
bill_cols = [col for col in data.columns if 'bill' in col]

# %%
sns.pairplot(data[bill_cols+['default']],hue='default')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-19-dd14314960d5> in <module>
# ----> 1 sns.pairplot(data[bill_cols+['default']],hue='default')
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/seaborn/distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     538             raise ValueError(msg)
#     539
# --> 540         self._compute_covariance()
#     541
#     542     def _compute_covariance(self):
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     550                                                bias=False,
#     551                                                aweights=self.weights))
# --> 552             self._data_inv_cov = linalg.inv(self._data_covariance)
#     553
#     554         self.covariance = self._data_covariance * self.factor**2
#
# ~/anaconda3/envs/tfpy3/lib/python3.7/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     972         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     973     if info > 0:
# --> 974         raise LinAlgError("singular matrix")
#     975     if info < 0:
#     976         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### Box plot
#
#
# </div>

# %% [markdown]
# ### Box plot of age feature

# %%
fig, ax = plt.subplots()
ax.boxplot(data['age'])
ax.set_title('Box plot for age feature')
# Out:
# Text(0.5, 1.0, 'Box plot for age feature')

# %%
### Box plot of limit_bal feature

# %%
fig, ax = plt.subplots()
ax.boxplot(data['limit_bal'])
ax.set_title('Box plot for limit_bal feature')
# Out:
# Text(0.5, 1.0, 'Box plot for limit_bal feature')

# %% [markdown]
# ### Grouped boxplot

# %%
data['bill6_pay5'] = data['bill_amt6'] - data['pay_amt5']

# %%
fig,ax = plt.subplots(figsize=(10,5))
sns.boxplot(x='education',y='bill6_pay5',data=data,showfliers=False)

# %%
fig,ax = plt.subplots(figsize=(10,5))
sns.boxplot(x='education',y='bill6_pay5',data=data,showfliers=False,hue='default')

# %% [markdown]
# <div class='alert alert-block alert-success' style="font-weight:bolder">
#
# ### Task3
#
# ### 1- Plot boxplot for 'default' and 'bill_mnt' for all months
#
# ### 2- Plot boxplot for 'default' and difference between 'bill_mnt_n' and 'pay_mnt_(n-1)' for all months
#
# </div>

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,10))

for i in range(2):
    for j in range(3):
        ix = i*3+j+1
        sns.boxplot(x='default',y='bill_amt{}'.format(ix), data=data, showfliers=False, hue='default',ax=axs[i, j])

# %%
# get the difference between pay and bill
for i in range(1, 6):
    ba = 'bill_amt{}'.format(i+1)
    pa = 'pay_amt{}'.format(i)
    bd = 'bill{}_pay{}'.format(i+1, i)
    data[bd] = data[ba] - data[pa]

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,10))

# plot difference
for i in range(2):
    for j in range(3):
        
        # skip last one
        if i == 1 and j == 2:
            continue
            
        ix = i*3+j+1
        fmt = 'bill{}_pay{}'.format(ix+1, ix)
        sns.boxplot(x='default',y=fmt, data=data, showfliers=False, hue='default',ax=axs[i, j])

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### Violin plot
#
#
# </div>

# %% [markdown]
# ### Seaborn: Violinplot of 'age' feature

# %%
sns.violinplot(x='age',data=data)

# %%
fig,ax = plt.subplots(figsize=(10,5))
sns.violinplot(x='education',y='bill6_pay5',data=data,scale='width',split=True,hue='default',showextrema=False)
ax.set_ylim(-100000,300000)
# Out:
# (-100000, 300000)

# %% [markdown]
# <div class='alert alert-block alert-warning' style='font-size:150%'>
#
# ### 3D plot
#
#
# </div>

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['age'],data['bill_amt6'],data['pay_amt5'],c=data['default'])
ax.view_init(30,0)
ax.set_xlabel('age')
ax.set_ylabel('bill_amt6')
ax.set_zlabel('pay_amt5')
# Out:
# Text(0.5, 0, 'pay_amt5')

# %% [markdown]
# <div class='alert alert-block alert-success' style="font-weight:bolder">
#
# ### Task4
#
# ### Try different combination of feature for 3d plot to check for possibility of finding interesting patterns
#
#
# </div>

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['age'],data['bill_amt1'], data['pay_amt1'],c=data['default'])
ax.view_init(30,0)
ax.set_xlabel('age')
ax.set_ylabel('bill_amt1')
ax.set_zlabel('pay_amt1')
# Out:
# Text(0.5, 0, 'pay_amt1')

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['age'],data['bill_amt2'], data['pay_amt3'],c=data['default'])
ax.view_init(30,0)
ax.set_xlabel('age')
ax.set_ylabel('bill_amt2')
ax.set_zlabel('pay_amt3')
# Out:
# Text(0.5, 0, 'pay_amt3')

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['education'],data['bill_amt5'], data['pay_amt4'],c=data['default'])
ax.view_init(30,0)
ax.set_xlabel('education')
ax.set_ylabel('bill_amt5')
ax.set_zlabel('pay_amt4')
# Out:
# Text(0.5, 0, 'pay_amt4')
